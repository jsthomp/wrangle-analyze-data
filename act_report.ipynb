# %% [markdown]
# ### We Rate Dogs Analysis for name and breed
# by James Thompson

# %% [markdown]
# Twitter page “We Rate Dogs” is a popular page where dogs are rated based on images posted to the Twitter page.  Of course, none of this is an “Official” rating but is based on a 1 -10 scale; however, that is all relative to the viewer’s opinion and the dog’s worthiness of a score higher than 10.  Like all Twitter accounts and other social media outlets, there are abilities to count or mark certain pictures as favorites or vote utilizing the provided scale or higher as we previously discussed.  So let’s do a little exploring.  As a canine enthusiast myself I like dog names and breeds. Names are interesting and I always believed that should reflect the attitude and behavior of the animal.  To better align ourselves with this exploring adventure, we have utilized Udacity’s data information from “We Rate Dogs” Twitter archive downloads and gathered some fun information related to names and breeds.
# Based on timestamp information from the data archives it appears that data entries to this Twitter account started in late 2015 and exist until mid to 2017.   For this time period what names have the most favorites for the site.  To determine this we must view the data and upon exploration, we will discover that not all data entries relate to dogs.  To deal strictly deal with dog names all names not related to dogs must be removed or a separate data frame must be created.  Having done this previously, one would find the following:

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# The dog name Duddles has the highest percentage of favorites for the Twitter page.  As there is a large amount of dog on the page the search was limited to the top 5 names.
#
# Now that we have the highest favorite dog names,   What are  the dog names with the highest average rating.  To determine this the same list from above will be used and the rating numerator from the data set will be analyzed.  There may be many dogs with the same name so an average of the rating will be taken for each dog name.

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# The list clearly indicates that the dog name Logan has the highest ratings.
#
# Lastly, what breed has the highest rating.  Again, the data set will be analyzed for just dogs and their breed.  The top 20 breed of dogs is displayed below.

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %% [markdown]
# The breed of clumber has the highest rating of all dogs.
# My comedic conclusion to this that if you want a dog to show off on Twitter or social media then you should get a dog of the breed clumber and name you dog the silliest name you can come up with and take lots of pictures.
